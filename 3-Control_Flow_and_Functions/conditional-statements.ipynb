# %% [markdown]
# # Conditional statements
#
# In Python, we often need to make decisions in the code based on certain conditions. The contropl flow statements help us define these conditions and control how the code behaves based on the inputs and states of variables. The most common used conditional statements in Pythoin are `if`, `elif` (short for "else if") and `else`.
#
# ## Control flow for decision making

# %%
condition_1 = 4 % 2 == 0
condition_2 = 5 % 2 == 0

if condition_1:
    # Block of code excute if condition_1 is True
    print()
elif condition_2:
    # Block of code executed if condition_1 if False and condition_2 is True
    print()
else:
    # Block of code exexcuted if both condition_1 and condition_2 are False
    print()

# %% [markdown]
# ## Practical examples with mathematical logic

# %%
number = int(input("Enter a number: "))

if number > 0:
    print("The number is positive.")
elif number < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# The nmber is positive.
