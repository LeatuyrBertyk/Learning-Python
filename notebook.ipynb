# %%
# Sample Python code for a new Jupyter Notebook cell

message = "Hello, Jupyter Notebook!"
print(message)

numbers = [1, 2, 3, 4, 5]
squared = [n ** 2 for n in numbers]

print("Squared numbers:", squared)
# Out:
# Hello, Jupyter Notebook!
# Squared numbers: [1, 4, 9, 16, 25]

# %%
a = 2
print(a**2)
# Out:
# 4
