# %% [markdown]
# # Pandas library in Python
#
# ## Pandas introduction
#
# ## What is Pandas
#
# Pandas is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and mnipulation data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.
#
# ### Why use Pandas?
#
# Pandas allows use to analyze big data and make conclusions based on statistical theories. Pandas can clean messy data sets, and make them readable and relevent. Relevent data is very importsnt in data science.
#
# ### What can Pandas do?
#
# Pandas gives you answers about the data, like:
#
# - Is there a correlation between two and more columns?
# - What is average value?
# - Max value?
# - Min value?
#
# Pandas are also able to delte rows that are not relevant, or contains wrong values, like empty or NULL values. This is called _cleaning_ data.
#
# ### Where is the Pandas Codebase?
#
# The source code for Pandas is located at this GitHub repository: [Pandas](https://github.com/pandas-dev/pandas).
#
# ## Example

# %%
import pandas as pd

mydataset = {
    'cars': ["BMW", "Volvo", "Ford"],
    'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
# ## Pandas Series and Labels
#
# A Pandas Series is like a column in a table. It isa one-dimensional array holding data of any type.
#
# If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1, etc. This label can be used to access a specified value.

# %%
import pandas as pd

# Create a Series from a list
a = [4, 5, 6]
myvar = pd.Series(a)

# Print the Series
print(myvar) 

# Indexing Series
print(myvar[0]) # Return the first value of the Series
# Out:
# 0    4
# 1    5
# 2    6
# dtype: int64
# 4

# %% [markdown]
# ### Create labels
#
# With the `index` argumant, you can name you own labels.

# %%
import pandas as pd

# Create labels
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
print(myvar["x"])
# Out:
# x    4
# y    5
# z    6
# dtype: int64
# 4

# %% [markdown]
# ### Key-Value Objects as Series
#
# You can also use a key.value object, like a dictionary, when creating a Series.
#
# Then, the keys of the dictionary become the labels. To select onlysome of the items in the dictionary, use the `index` argument and specify only the tems you want to include in the Series.

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

# Create Series from a dictionary
myvar = pd.Series(calories)
print(myvar)

# Create Series with index
myvar = pd.Series(calories, index = ["day1", "day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# ## DataFrames
#
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames. Series is like a column, a DataFrame is the whole table.

# %%
import pandas as pd

data = {
    "calories": [420, 380, 390, 400, 410, 400, 460],
    "duration": [50, 40, 45, 50, 50, 45, 55]
}

df = pd.DataFrame(data)

print(f"Max rows: {pd.options.display.max_rows}") # Max rows that DataFrame can display
print(df)

# Print header and first lines of the DataFrame
print(df.head())  # Print header and first 5 lines of the DataFrame
print(df.head(2)) # Print header and first 2 lines of the DataFrame

# Print header and last lines of the DataFrame
print(df.tail())  #Print header and last 5 lines of the DataFrame
print(df.tail(3)) # Print header and last 3 lines of the DataFrame
# Out:
# Max rows: 60
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# 3       400        50
# 4       410        50
# 5       400        45
# 6       460        55
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# 3       400        50
# 4       410        50
#    calories  duration
# 0       420        50
# 1       380        40
#    calories  duration
# 2       390        45
# 3       400        50
# 4       410        50
# 5       400        45
# 6       460        55
#    calories  duration
# 4       410        50
# 5       400        45
# 6       460        55

# %% [markdown]
# ### Locate row
#
# As you can see from the result above, the DataFrame is like a table with rows and columns.
#
# Pandas use the `loc` attribute to return one or more specified row(s).

# %%
import pandas as  pd

data = {
    "calories": ["420", "380", "390"],
    "duration": [50, 40, 45]
}

df = pd.DataFrame(data)
print(df)

# Return a Pandas Series
print(df.loc[0])

# Use a list of indexes
print(df.loc[[0, 1]])
# Out:
#   calories  duration
# 0      420        50
# 1      380        40
# 2      390        45
# calories    420
# duration     50
# Name: 0, dtype: object
#   calories  duration
# 0      420        50
# 1      380        40

# %% [markdown]
# ### Named indexes
#
# With the `index` argument, you can name your own indexes.

# %%
import pandas as pd

data = {
    "calories": [420,380, 390],
    "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)

print(df.loc["day1"])
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# calories    420
# duration     50
# Name: day1, dtype: int64

# %% [markdown]
# ### Load files into a DataFrame
#
# If your data sets are stored in a file, Pandas can load them into a DatFrame.

# %%
import pandas as pd

# Load DataFrame from a .csv file
df = pd.read_csv('data.csv')
print(df)

# Load DataFrame from a .json file
df = pd.read_json('data.json')
print(df)
# Out:
# 60

# %% [markdown]
# ## Cleaning Data by Pandas
#
# Data cleaning means fixing bad data in your data set. Bad data could be:
#
# - Empty cells
# - Data in wrong format
# - Wrong data
# - Duplicates

# %%
import pandas as pd

# Load data set
df = pd.read_csv('fitness_data.csv')

# Print header to check
print(df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# ### Cleaning empty cells
#
# Empty cells can potentially give you a wrong result when you analyze data.
#
# #### Remove rows
#
# One way to deal with empty cells is to remove rows that contain empty cells. This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result

# %%
import pandas as pd

df = pd.read_csv('fitness_data.csv')

new_df = df.dropna() # Create new DataFrame
#df.dropna(inplace = True) # Fix in-place

print(new_df)
#print(df.dropna(inplace = True))
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# #### Replace empty values
#
# Another way of dealing with empty cells is to insert a new value instead. This way you do not have to delete entire rows just beacuse of some empty cells.
#
# The `fillna()` method allows us to replace empty celles with a value.

# %%
import pandas as pd

df = pd.read_csv('fitness_data.csv')

# Replace all
#df.fillna(130, inplace = True) # Replace NULL values by 130

# Replace for specified columns
df.fillna({"Calories": 130}, inplace = True)

# Replace using Mean, Median, or Mode
mean = df["Calories"].mean()
df.fillna({"Calories": mean}, inplace = True)

median = df["Calories"].median()
df.fillna({"Calories": median}, inplace = True)

mode = df["Calories"].mode()
df.fillna({"Calories": mode}, inplace = True)

# %% [markdown]
# **Mean** = the average value (the sum of all values divided by number of values).
#
# **Median** = the value in the middle, after you have sorted all values ascending.
#
# **Mode** = the value that appears most frequently.

# %% [markdown]
# ## Cleaning data of wrong format
#
# Cells with data of wrong format can make it difficult, or even impossible, to analyze data. To fix it, you have two options: remove the rows, or convert all cells in the columns into the same format.
#
# ### Convert into a correct format
#
# In our DataFrame, we have two cells with the wrong format. Check out the row 22 and 26, the 'Date' column should a string that represents a data.
#
# Let's try to convert all cells in the 'Data' column into dates. Pandas has a `to_datetime()` method for this.

# %%
import pandas as pd

df = pd.read_csv('fitness_data.csv')

df["Date"] = pd.to_datetime(df["Date"], format = 'mixed')

print(df)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# ### Removing rows
#
# The result from the converting in the example above gave us a NaT value, which can be handled as a NULL value, and we can remove the row by using the `dropna()` method.

# %%
import pandas as pd

df = pd.read_csv('fitness_data.csv')

df["Date"] = pd.to_datetime(df["Date"], format = "mixed")

df.dropna(subset=["Date"], inplace = True)

print(df)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# ## Fixing wrong data
#
# "Wrong data" does not have to be "empty cells" or "wrong format", it can just be wrong, ike if someone registered "199" instead of "1.99".
#
# Sometimes, you can spot wrong data by looking at the data set, because you have an expectaton of what it should be. If you take a look at our data set, you can see that in row 7, the duration is 450 but for all the other rows the duration is between 30 and 60. It doesn;t have to be wrong, but taking in consideration tat this is the data set of someones's workout sessions, we conclude with the fact that this person did not work out in 450 minutes.
#
# ### Replacing values
#
# One way to fix wrong values is to replace them with something else. In our example, it is most likely a typo, and the value should be "45" instead of "450", and we could just insert "45" in row 7.

# %%
import pandas as pd

df = pd.read_csv('fitness_data.csv')

df.loc[7, "Duration"] = 45

print(df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7         45  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# For small data sets you might be able to replace the wrong data one by one,but not for big data sets. To replace wrong data for larger data sets you can create some rules, e.g. set some boundaries for legal values, and replace any values that are outside of the boundaries.

# %%
import pandas as pd

df = pd.read_csv('fitness_data.csv')

for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.loc[x, "Duration"] = 120

print(df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        120  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# ### Removing rows
#
# Another way to handing wrong data is to remove the rows that contains wrong data. This way you do not have to find out what to replace them with, and there is a good chance you do not need them to do your analyses.

# %%
import pandas as pd

df = pd.read_csv('fitness_data.csv')

for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.drop(x, inplace = True)

print(df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# 17        60  2020/12/17    100       120     300.0
# ...

# %% [markdown]
# ## Removing dupicates
#
# Duplicate rows are rows that have been  registered more than one time.
#
# To discover duplicates, we can use the `duplicated()` method. It returns a Bollean values for reach row.

# %%
import pandas as pd

df = pd.read_csv('fitness_data.csv')

print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %% [markdown]
# ### Removing duplicates
#
# To remove duplicates, use the `drop_duplicates()` method.

# %%
import pandas as pd

df = pd.read_csv('fitness_data.csv')

df.drop_duplicates(inplace = True)
print(df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# 17        60  2020/12/17    100       120     300.0
# ...

# %% [markdown]
# ## Plotting
#
# Pandas uses the `plot()` method to create diagrams. We can use Pylot, a submodule of the Matplotlib library to visulize the diagram on the screen.
#
# ### Scatter plot
#
# Specify that you wan to scatter plot with the `kind` argument: `kind = 'scatter'`. A scatter plot needs an x- and a y-axis.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')

df.plot(kind = 'scatter', x = "Duration", y = "Calories")

plt.show()

# %% [markdown]
# ### Histogram
#
# Sue the `kind` argument to specify that you want a histogram: `kind='hist'`. A hustogram needs only one column. A histogram shows use the frequency of seach interval, e.g. how many workouts lasted between 50 and 60 minutes?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')

df["Duration"].plot(kind = 'hist')

plt.show()
