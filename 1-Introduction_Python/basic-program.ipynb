# %%
# 1. Hello world

print("Hello, world!")
# Out:
# Hello, world!

# %%
# 2. Simple mathmatical calculations in Python

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
product = num1 * num2

print(f"The sum is {sum}")
print(f"The product is {product}")
# Out:
# The sum is 9.0
# The product is 20.0
